# %% [markdown]
# # GP Regression with Uncertain Inputs
#
# ## Introduction
#
# In this notebook, we're going to demonstrate one way of dealing with uncertainty in our training data. Let's say that we're collecting training data that models the following function.
#
# $$
# \begin{align}
# y &= \sin(2\pi x) + \epsilon \\
#   \epsilon &\sim \mathcal{N}(0, 0.2)
# \end{align}
# $$
#
# However, now assume that we're a bit uncertain about our features. In particular, we're going to assume that every `x_i` value is not a point but a distribution instead. E.g.
#
# $$ x_i \sim \mathcal{N}(\mu_i, \sigma_i). $$

# %% [markdown]
# ### Using a distributional kernel to deal with uncertain inputs
#
# Rather than using a variational method (see the GP Regression with Uncertian Inputs tutorial in the variational examples), if we explicitly know the type of uncertainty in our inputs we can pass that into our kernel.
#
# More specifically, assuming Gaussian inputs, we will compute the symmetrized KL divergence between the Gaussian inputs.

# %%
import math
import torch
import tqdm
import gpytorch
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Training data is 100 points in [0,1] inclusive regularly spaced
train_x_mean = torch.linspace(0, 1, 20)
# We'll assume the variance shrinks the closer we get to 1
train_x_stdv = torch.linspace(0.03, 0.01, 20)

# True function is sin(2*pi*x) with Gaussian noise
train_y = torch.sin(train_x_mean * (2 * math.pi)) + torch.randn(train_x_mean.size()) * 0.2

# %% [markdown]
# To effectively pass in the training distributional data, we will need to stack the mean and log variances.

# %%
train_x_distributional = torch.stack((train_x_mean, (train_x_stdv**2).log()), dim=1)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 3))
ax.errorbar(train_x_mean, train_y, xerr=(train_x_stdv * 2), fmt="k*", label="Train Data")
ax.legend()

# %% [markdown]
# We train the hyperparameters of the resulting distributional GP via type-II gradient descent, as is standard in many settings. We could also do fully Bayesian inference.

# %%
from gpytorch.models import ExactGP
from gpytorch.kernels import GaussianSymmetrizedKLKernel, ScaleKernel
from gpytorch.means import ConstantMean

class ExactGPModel(ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = ConstantMean()
        self.covar_module = ScaleKernel(GaussianSymmetrizedKLKernel())
        
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x_distributional, train_y, likelihood)

# %%
# this is for running the notebook in our testing framework
import os
smoke_test = ('CI' in os.environ)
training_iter = 2 if smoke_test else 500


# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.25)  # Includes GaussianLikelihood parameters

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x_distributional)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/500 - Loss: 1.267   lengthscale: 0.693   noise: 0.693
# Iter 2/500 - Loss: 1.238   lengthscale: 0.826   noise: 0.576
# Iter 3/500 - Loss: 1.164   lengthscale: 0.974   noise: 0.475
# Iter 4/500 - Loss: 1.129   lengthscale: 1.112   noise: 0.389
# Iter 5/500 - Loss: 1.111   lengthscale: 1.247   noise: 0.317
# Iter 6/500 - Loss: 1.085   lengthscale: 1.396   noise: 0.260
# Iter 7/500 - Loss: 1.078   lengthscale: 1.562   noise: 0.218
# Iter 8/500 - Loss: 1.101   lengthscale: 1.745   noise: 0.189
# Iter 9/500 - Loss: 1.106   lengthscale: 1.942   noise: 0.174
# Iter 10/500 - Loss: 1.089   lengthscale: 2.152   noise: 0.169
# Iter 11/500 - Loss: 1.074   lengthscale: 2.373   noise: 0.171
# Iter 12/500 - Loss: 1.063   lengthscale: 2.602   noise: 0.177
# Iter 13/500 - Loss: 1.047   lengthscale: 2.840   noise: 0.184
# Iter 14/500 - Loss: 1.029   lengthscale: 3.086   noise: 0.192
# Iter 15/500 - Loss: 1.018   lengthscale: 3.338   noise: 0.197
# Iter 16/500 - Loss: 1.013   lengthscale: 3.593   noise: 0.198
# Iter 17/500 - Loss: 1.009   lengthscale: 3.851   noise: 0.195
# Iter 18/500 - Loss: 1.002   lengthscale: 4.109   noise: 0.188
# Iter 19/500 - Loss: 0.991   lengthscale: 4.367   noise: 0.178
# Iter 20/500 - Loss: 0.978   lengthscale: 4.626   noise: 0.164
# Iter 21/500 - Loss: 0.964   lengthscale: 4.887   noise: 0.149
# Iter 22/500 - Loss: 0.950   lengthscale: 5.148   noise: 0.133
# Iter 23/500 - Loss: 0.934   lengthscale: 5.411   noise: 0.117
# Iter 24/500 - Loss: 0.917   lengthscale: 5.676   noise: 0.102
# Iter 25/500 - Loss: 0.899   lengthscale: 5.943   noise: 0.088
# Iter 26/500 - Loss: 0.882   lengthscale: 6.211   noise: 0.075
# Iter 27/500 - Loss: 0.867   lengthscale: 6.481   noise: 0.064
# Iter 28/500 - Loss: 0.854   lengthscale: 6.752   noise: 0.054
# Iter 29/500 - Loss: 0.841   lengthscale: 7.023   noise: 0.046
# Iter 30/500 - Loss: 0.827   lengthscale: 7.295   noise: 0.039
# Iter 31/500 - Loss: 0.814   lengthscale: 7.567   noise: 0.034
# Iter 32/500 - Loss: 0.802   lengthscale: 7.838   noise: 0.029
# Iter 33/500 - Loss: 0.792   lengthscale: 8.107   noise: 0.025
# Iter 34/500 - Loss: 0.783   lengthscale: 8.373   noise: 0.021
# Iter 35/500 - Loss: 0.774   lengthscale: 8.635   noise: 0.018
# Iter 36/500 - Loss: 0.767   lengthscale: 8.891   noise: 0.016
# Iter 37/500 - Loss: 0.762   lengthscale: 9.142   noise: 0.014
# Iter 38/500 - Loss: 0.758   lengthscale: 9.385   noise: 0.013
# Iter 39/500 - Loss: 0.754   lengthscale: 9.619   noise: 0.011
# Iter 40/500 - Loss: 0.751   lengthscale: 9.843   noise: 0.010
# Iter 41/500 - Loss: 0.749   lengthscale: 10.056   noise: 0.009
# Iter 42/500 - Loss: 0.748   lengthscale: 10.256   noise: 0.008
# Iter 43/500 - Loss: 0.749   lengthscale: 10.442   noise: 0.008
# Iter 44/500 - Loss: 0.749   lengthscale: 10.612   noise: 0.007
# Iter 45/500 - Loss: 0.750   lengthscale: 10.764   noise: 0.007
# Iter 46/500 - Loss: 0.751   lengthscale: 10.899   noise: 0.006
# Iter 47/500 - Loss: 0.751   lengthscale: 11.015   noise: 0.006
# Iter 48/500 - Loss: 0.752   lengthscale: 11.113   noise: 0.006
# Iter 49/500 - Loss: 0.753   lengthscale: 11.192   noise: 0.006
# Iter 50/500 - Loss: 0.754   lengthscale: 11.255   noise: 0.006
# Iter 51/500 - Loss: 0.754   lengthscale: 11.302   noise: 0.006
# Iter 52/500 - Loss: 0.755   lengthscale: 11.333   noise: 0.006
# Iter 53/500 - Loss: 0.755   lengthscale: 11.352   noise: 0.006
# Iter 54/500 - Loss: 0.755   lengthscale: 11.358   noise: 0.006
# Iter 55/500 - Loss: 0.755   lengthscale: 11.352   noise: 0.006
# Iter 56/500 - Loss: 0.754   lengthscale: 11.337   noise: 0.006
# Iter 57/500 - Loss: 0.754   lengthscale: 11.312   noise: 0.006
# Iter 58/500 - Loss: 0.753   lengthscale: 11.279   noise: 0.006
# Iter 59/500 - Loss: 0.752   lengthscale: 11.239   noise: 0.006
# Iter 60/500 - Loss: 0.751   lengthscale: 11.192   noise: 0.007
# Iter 61/500 - Loss: 0.751   lengthscale: 11.141   noise: 0.007
# Iter 62/500 - Loss: 0.750   lengthscale: 11.087   noise: 0.007
# Iter 63/500 - Loss: 0.749   lengthscale: 11.031   noise: 0.008
# Iter 64/500 - Loss: 0.748   lengthscale: 10.975   noise: 0.008
# Iter 65/500 - Loss: 0.748   lengthscale: 10.920   noise: 0.008
# Iter 66/500 - Loss: 0.747   lengthscale: 10.867   noise: 0.009
# Iter 67/500 - Loss: 0.747   lengthscale: 10.819   noise: 0.009
# Iter 68/500 - Loss: 0.747   lengthscale: 10.775   noise: 0.010
# Iter 69/500 - Loss: 0.746   lengthscale: 10.737   noise: 0.010
# Iter 70/500 - Loss: 0.746   lengthscale: 10.704   noise: 0.011
# Iter 71/500 - Loss: 0.746   lengthscale: 10.678   noise: 0.011
# Iter 72/500 - Loss: 0.746   lengthscale: 10.659   noise: 0.012
# Iter 73/500 - Loss: 0.745   lengthscale: 10.647   noise: 0.012
# Iter 74/500 - Loss: 0.745   lengthscale: 10.643   noise: 0.013
# Iter 75/500 - Loss: 0.745   lengthscale: 10.645   noise: 0.014
# Iter 76/500 - Loss: 0.745   lengthscale: 10.656   noise: 0.014
# Iter 77/500 - Loss: 0.744   lengthscale: 10.673   noise: 0.015
# Iter 78/500 - Loss: 0.744   lengthscale: 10.698   noise: 0.016
# Iter 79/500 - Loss: 0.744   lengthscale: 10.730   noise: 0.016
# Iter 80/500 - Loss: 0.743   lengthscale: 10.770   noise: 0.017
# Iter 81/500 - Loss: 0.743   lengthscale: 10.816   noise: 0.018
# Iter 82/500 - Loss: 0.742   lengthscale: 10.869   noise: 0.018
# Iter 83/500 - Loss: 0.741   lengthscale: 10.929   noise: 0.019
# Iter 84/500 - Loss: 0.741   lengthscale: 10.995   noise: 0.020
# Iter 85/500 - Loss: 0.740   lengthscale: 11.067   noise: 0.020
# Iter 86/500 - Loss: 0.739   lengthscale: 11.144   noise: 0.021
# Iter 87/500 - Loss: 0.738   lengthscale: 11.228   noise: 0.022
# Iter 88/500 - Loss: 0.737   lengthscale: 11.316   noise: 0.023
# Iter 89/500 - Loss: 0.736   lengthscale: 11.410   noise: 0.023
# Iter 90/500 - Loss: 0.735   lengthscale: 11.509   noise: 0.024
# Iter 91/500 - Loss: 0.734   lengthscale: 11.613   noise: 0.025
# Iter 92/500 - Loss: 0.732   lengthscale: 11.722   noise: 0.026
# Iter 93/500 - Loss: 0.731   lengthscale: 11.835   noise: 0.027
# Iter 94/500 - Loss: 0.729   lengthscale: 11.953   noise: 0.028
# Iter 95/500 - Loss: 0.728   lengthscale: 12.076   noise: 0.029
# Iter 96/500 - Loss: 0.726   lengthscale: 12.204   noise: 0.030
# Iter 97/500 - Loss: 0.725   lengthscale: 12.336   noise: 0.031
# Iter 98/500 - Loss: 0.723   lengthscale: 12.472   noise: 0.032
# Iter 99/500 - Loss: 0.721   lengthscale: 12.613   noise: 0.033
# Iter 100/500 - Loss: 0.719   lengthscale: 12.758   noise: 0.034
# Iter 101/500 - Loss: 0.717   lengthscale: 12.908   noise: 0.035
# Iter 102/500 - Loss: 0.716   lengthscale: 13.061   noise: 0.036
# Iter 103/500 - Loss: 0.714   lengthscale: 13.218   noise: 0.037
# Iter 104/500 - Loss: 0.712   lengthscale: 13.379   noise: 0.037
# Iter 105/500 - Loss: 0.709   lengthscale: 13.543   noise: 0.038
# Iter 106/500 - Loss: 0.707   lengthscale: 13.710   noise: 0.039
# Iter 107/500 - Loss: 0.705   lengthscale: 13.880   noise: 0.039
# Iter 108/500 - Loss: 0.703   lengthscale: 14.052   noise: 0.039
# Iter 109/500 - Loss: 0.701   lengthscale: 14.226   noise: 0.039
# Iter 110/500 - Loss: 0.699   lengthscale: 14.402   noise: 0.040
# Iter 111/500 - Loss: 0.696   lengthscale: 14.580   noise: 0.040
# Iter 112/500 - Loss: 0.694   lengthscale: 14.760   noise: 0.040
# Iter 113/500 - Loss: 0.692   lengthscale: 14.941   noise: 0.040
# Iter 114/500 - Loss: 0.690   lengthscale: 15.123   noise: 0.040
# Iter 115/500 - Loss: 0.688   lengthscale: 15.305   noise: 0.040
# Iter 116/500 - Loss: 0.685   lengthscale: 15.489   noise: 0.041
# Iter 117/500 - Loss: 0.683   lengthscale: 15.674   noise: 0.041
# Iter 118/500 - Loss: 0.681   lengthscale: 15.859   noise: 0.041
# Iter 119/500 - Loss: 0.678   lengthscale: 16.044   noise: 0.041
# Iter 120/500 - Loss: 0.676   lengthscale: 16.230   noise: 0.042
# Iter 121/500 - Loss: 0.674   lengthscale: 16.416   noise: 0.042
# Iter 122/500 - Loss: 0.672   lengthscale: 16.603   noise: 0.042
# Iter 123/500 - Loss: 0.670   lengthscale: 16.789   noise: 0.043
# Iter 124/500 - Loss: 0.667   lengthscale: 16.976   noise: 0.043
# Iter 125/500 - Loss: 0.665   lengthscale: 17.163   noise: 0.043
# Iter 126/500 - Loss: 0.663   lengthscale: 17.349   noise: 0.043
# Iter 127/500 - Loss: 0.661   lengthscale: 17.536   noise: 0.043
# Iter 128/500 - Loss: 0.659   lengthscale: 17.722   noise: 0.043
# Iter 129/500 - Loss: 0.657   lengthscale: 17.908   noise: 0.043
# Iter 130/500 - Loss: 0.655   lengthscale: 18.093   noise: 0.043
# Iter 131/500 - Loss: 0.653   lengthscale: 18.278   noise: 0.043
# Iter 132/500 - Loss: 0.651   lengthscale: 18.462   noise: 0.043
# Iter 133/500 - Loss: 0.649   lengthscale: 18.646   noise: 0.043
# Iter 134/500 - Loss: 0.647   lengthscale: 18.829   noise: 0.043
# Iter 135/500 - Loss: 0.645   lengthscale: 19.011   noise: 0.043
# Iter 136/500 - Loss: 0.643   lengthscale: 19.193   noise: 0.043
# Iter 137/500 - Loss: 0.641   lengthscale: 19.373   noise: 0.043
# Iter 138/500 - Loss: 0.639   lengthscale: 19.553   noise: 0.043
# Iter 139/500 - Loss: 0.637   lengthscale: 19.732   noise: 0.043
# Iter 140/500 - Loss: 0.635   lengthscale: 19.911   noise: 0.043
# Iter 141/500 - Loss: 0.633   lengthscale: 20.088   noise: 0.043
# Iter 142/500 - Loss: 0.632   lengthscale: 20.264   noise: 0.043
# Iter 143/500 - Loss: 0.630   lengthscale: 20.440   noise: 0.043
# Iter 144/500 - Loss: 0.628   lengthscale: 20.614   noise: 0.043
# Iter 145/500 - Loss: 0.626   lengthscale: 20.788   noise: 0.043
# Iter 146/500 - Loss: 0.625   lengthscale: 20.960   noise: 0.043
# Iter 147/500 - Loss: 0.623   lengthscale: 21.131   noise: 0.043
# Iter 148/500 - Loss: 0.621   lengthscale: 21.302   noise: 0.043
# Iter 149/500 - Loss: 0.620   lengthscale: 21.471   noise: 0.043
# Iter 150/500 - Loss: 0.618   lengthscale: 21.639   noise: 0.043
# Iter 151/500 - Loss: 0.617   lengthscale: 21.806   noise: 0.043
# Iter 152/500 - Loss: 0.615   lengthscale: 21.972   noise: 0.043
# Iter 153/500 - Loss: 0.614   lengthscale: 22.137   noise: 0.043
# Iter 154/500 - Loss: 0.612   lengthscale: 22.301   noise: 0.043
# Iter 155/500 - Loss: 0.611   lengthscale: 22.463   noise: 0.043
# Iter 156/500 - Loss: 0.609   lengthscale: 22.625   noise: 0.043
# Iter 157/500 - Loss: 0.608   lengthscale: 22.785   noise: 0.043
# Iter 158/500 - Loss: 0.607   lengthscale: 22.944   noise: 0.043
# Iter 159/500 - Loss: 0.605   lengthscale: 23.102   noise: 0.043
# Iter 160/500 - Loss: 0.604   lengthscale: 23.259   noise: 0.043
# Iter 161/500 - Loss: 0.603   lengthscale: 23.415   noise: 0.042
# Iter 162/500 - Loss: 0.601   lengthscale: 23.569   noise: 0.042
# Iter 163/500 - Loss: 0.600   lengthscale: 23.723   noise: 0.042
# Iter 164/500 - Loss: 0.599   lengthscale: 23.875   noise: 0.042
# Iter 165/500 - Loss: 0.598   lengthscale: 24.026   noise: 0.042
# Iter 166/500 - Loss: 0.596   lengthscale: 24.176   noise: 0.042
# Iter 167/500 - Loss: 0.595   lengthscale: 24.325   noise: 0.042
# Iter 168/500 - Loss: 0.594   lengthscale: 24.473   noise: 0.042
# Iter 169/500 - Loss: 0.593   lengthscale: 24.620   noise: 0.042
# Iter 170/500 - Loss: 0.592   lengthscale: 24.765   noise: 0.042
# Iter 171/500 - Loss: 0.591   lengthscale: 24.910   noise: 0.042
# Iter 172/500 - Loss: 0.590   lengthscale: 25.053   noise: 0.042
# Iter 173/500 - Loss: 0.589   lengthscale: 25.195   noise: 0.042
# Iter 174/500 - Loss: 0.588   lengthscale: 25.337   noise: 0.042
# Iter 175/500 - Loss: 0.587   lengthscale: 25.477   noise: 0.042
# Iter 176/500 - Loss: 0.586   lengthscale: 25.616   noise: 0.042
# Iter 177/500 - Loss: 0.585   lengthscale: 25.754   noise: 0.042
# Iter 178/500 - Loss: 0.584   lengthscale: 25.891   noise: 0.042
# Iter 179/500 - Loss: 0.583   lengthscale: 26.027   noise: 0.042
# Iter 180/500 - Loss: 0.582   lengthscale: 26.162   noise: 0.042
# Iter 181/500 - Loss: 0.581   lengthscale: 26.296   noise: 0.042
# Iter 182/500 - Loss: 0.580   lengthscale: 26.428   noise: 0.042
# Iter 183/500 - Loss: 0.579   lengthscale: 26.560   noise: 0.042
# Iter 184/500 - Loss: 0.578   lengthscale: 26.691   noise: 0.042
# Iter 185/500 - Loss: 0.577   lengthscale: 26.821   noise: 0.042
# Iter 186/500 - Loss: 0.576   lengthscale: 26.950   noise: 0.042
# Iter 187/500 - Loss: 0.576   lengthscale: 27.078   noise: 0.042
# Iter 188/500 - Loss: 0.575   lengthscale: 27.205   noise: 0.042
# Iter 189/500 - Loss: 0.574   lengthscale: 27.330   noise: 0.042
# Iter 190/500 - Loss: 0.573   lengthscale: 27.456   noise: 0.042
# Iter 191/500 - Loss: 0.572   lengthscale: 27.580   noise: 0.042
# Iter 192/500 - Loss: 0.572   lengthscale: 27.703   noise: 0.042
# Iter 193/500 - Loss: 0.571   lengthscale: 27.825   noise: 0.042
# Iter 194/500 - Loss: 0.570   lengthscale: 27.946   noise: 0.042
# Iter 195/500 - Loss: 0.569   lengthscale: 28.067   noise: 0.042
# Iter 196/500 - Loss: 0.569   lengthscale: 28.186   noise: 0.042
# Iter 197/500 - Loss: 0.568   lengthscale: 28.305   noise: 0.042
# Iter 198/500 - Loss: 0.567   lengthscale: 28.423   noise: 0.042
# Iter 199/500 - Loss: 0.567   lengthscale: 28.540   noise: 0.042
# Iter 200/500 - Loss: 0.566   lengthscale: 28.656   noise: 0.042
# Iter 201/500 - Loss: 0.565   lengthscale: 28.771   noise: 0.042
# Iter 202/500 - Loss: 0.565   lengthscale: 28.885   noise: 0.042
# Iter 203/500 - Loss: 0.564   lengthscale: 28.999   noise: 0.042
# Iter 204/500 - Loss: 0.563   lengthscale: 29.112   noise: 0.042
# Iter 205/500 - Loss: 0.563   lengthscale: 29.224   noise: 0.042
# Iter 206/500 - Loss: 0.562   lengthscale: 29.335   noise: 0.042
# Iter 207/500 - Loss: 0.562   lengthscale: 29.445   noise: 0.042
# Iter 208/500 - Loss: 0.561   lengthscale: 29.555   noise: 0.042
# Iter 209/500 - Loss: 0.561   lengthscale: 29.664   noise: 0.042
# Iter 210/500 - Loss: 0.560   lengthscale: 29.772   noise: 0.042
# Iter 211/500 - Loss: 0.559   lengthscale: 29.879   noise: 0.042
# Iter 212/500 - Loss: 0.559   lengthscale: 29.986   noise: 0.042
# Iter 213/500 - Loss: 0.558   lengthscale: 30.092   noise: 0.042
# Iter 214/500 - Loss: 0.558   lengthscale: 30.197   noise: 0.042
# Iter 215/500 - Loss: 0.557   lengthscale: 30.301   noise: 0.042
# Iter 216/500 - Loss: 0.557   lengthscale: 30.405   noise: 0.042
# Iter 217/500 - Loss: 0.556   lengthscale: 30.508   noise: 0.042
# Iter 218/500 - Loss: 0.556   lengthscale: 30.610   noise: 0.042
# Iter 219/500 - Loss: 0.555   lengthscale: 30.712   noise: 0.042
# Iter 220/500 - Loss: 0.555   lengthscale: 30.813   noise: 0.042
# Iter 221/500 - Loss: 0.554   lengthscale: 30.913   noise: 0.042
# Iter 222/500 - Loss: 0.554   lengthscale: 31.013   noise: 0.042
# Iter 223/500 - Loss: 0.553   lengthscale: 31.111   noise: 0.042
# Iter 224/500 - Loss: 0.553   lengthscale: 31.210   noise: 0.042
# Iter 225/500 - Loss: 0.552   lengthscale: 31.307   noise: 0.042
# Iter 226/500 - Loss: 0.552   lengthscale: 31.404   noise: 0.042
# Iter 227/500 - Loss: 0.552   lengthscale: 31.501   noise: 0.042
# Iter 228/500 - Loss: 0.551   lengthscale: 31.597   noise: 0.042
# Iter 229/500 - Loss: 0.551   lengthscale: 31.692   noise: 0.042
# Iter 230/500 - Loss: 0.550   lengthscale: 31.786   noise: 0.042
# Iter 231/500 - Loss: 0.550   lengthscale: 31.880   noise: 0.042
# Iter 232/500 - Loss: 0.550   lengthscale: 31.974   noise: 0.042
# Iter 233/500 - Loss: 0.549   lengthscale: 32.066   noise: 0.042
# Iter 234/500 - Loss: 0.549   lengthscale: 32.159   noise: 0.042
# Iter 235/500 - Loss: 0.548   lengthscale: 32.250   noise: 0.042
# Iter 236/500 - Loss: 0.548   lengthscale: 32.341   noise: 0.042
# Iter 237/500 - Loss: 0.548   lengthscale: 32.432   noise: 0.042
# Iter 238/500 - Loss: 0.547   lengthscale: 32.522   noise: 0.042
# Iter 239/500 - Loss: 0.547   lengthscale: 32.611   noise: 0.042
# Iter 240/500 - Loss: 0.546   lengthscale: 32.700   noise: 0.042
# Iter 241/500 - Loss: 0.546   lengthscale: 32.788   noise: 0.042
# Iter 242/500 - Loss: 0.546   lengthscale: 32.876   noise: 0.042
# Iter 243/500 - Loss: 0.545   lengthscale: 32.964   noise: 0.042
# Iter 244/500 - Loss: 0.545   lengthscale: 33.050   noise: 0.042
# Iter 245/500 - Loss: 0.545   lengthscale: 33.137   noise: 0.042
# Iter 246/500 - Loss: 0.544   lengthscale: 33.222   noise: 0.042
# Iter 247/500 - Loss: 0.544   lengthscale: 33.308   noise: 0.042
# Iter 248/500 - Loss: 0.544   lengthscale: 33.393   noise: 0.042
# Iter 249/500 - Loss: 0.543   lengthscale: 33.477   noise: 0.042
# Iter 250/500 - Loss: 0.543   lengthscale: 33.561   noise: 0.042
# Iter 251/500 - Loss: 0.543   lengthscale: 33.644   noise: 0.042
# Iter 252/500 - Loss: 0.543   lengthscale: 33.727   noise: 0.042
# Iter 253/500 - Loss: 0.542   lengthscale: 33.809   noise: 0.042
# Iter 254/500 - Loss: 0.542   lengthscale: 33.891   noise: 0.042
# Iter 255/500 - Loss: 0.542   lengthscale: 33.973   noise: 0.042
# Iter 256/500 - Loss: 0.541   lengthscale: 34.054   noise: 0.042
# Iter 257/500 - Loss: 0.541   lengthscale: 34.134   noise: 0.042
# Iter 258/500 - Loss: 0.541   lengthscale: 34.215   noise: 0.042
# Iter 259/500 - Loss: 0.540   lengthscale: 34.294   noise: 0.042
# Iter 260/500 - Loss: 0.540   lengthscale: 34.374   noise: 0.042
# Iter 261/500 - Loss: 0.540   lengthscale: 34.453   noise: 0.042
# Iter 262/500 - Loss: 0.540   lengthscale: 34.531   noise: 0.042
# Iter 263/500 - Loss: 0.539   lengthscale: 34.609   noise: 0.042
# Iter 264/500 - Loss: 0.539   lengthscale: 34.687   noise: 0.042
# Iter 265/500 - Loss: 0.539   lengthscale: 34.764   noise: 0.042
# Iter 266/500 - Loss: 0.539   lengthscale: 34.841   noise: 0.042
# Iter 267/500 - Loss: 0.538   lengthscale: 34.917   noise: 0.042
# Iter 268/500 - Loss: 0.538   lengthscale: 34.993   noise: 0.042
# Iter 269/500 - Loss: 0.538   lengthscale: 35.069   noise: 0.042
# Iter 270/500 - Loss: 0.538   lengthscale: 35.144   noise: 0.042
# Iter 271/500 - Loss: 0.537   lengthscale: 35.219   noise: 0.042
# Iter 272/500 - Loss: 0.537   lengthscale: 35.294   noise: 0.042
# Iter 273/500 - Loss: 0.537   lengthscale: 35.368   noise: 0.042
# Iter 274/500 - Loss: 0.537   lengthscale: 35.442   noise: 0.042
# Iter 275/500 - Loss: 0.536   lengthscale: 35.515   noise: 0.042
# Iter 276/500 - Loss: 0.536   lengthscale: 35.588   noise: 0.042
# Iter 277/500 - Loss: 0.536   lengthscale: 35.661   noise: 0.042
# Iter 278/500 - Loss: 0.536   lengthscale: 35.733   noise: 0.042
# Iter 279/500 - Loss: 0.535   lengthscale: 35.805   noise: 0.042
# Iter 280/500 - Loss: 0.535   lengthscale: 35.877   noise: 0.042
# Iter 281/500 - Loss: 0.535   lengthscale: 35.948   noise: 0.043
# Iter 282/500 - Loss: 0.535   lengthscale: 36.019   noise: 0.043
# Iter 283/500 - Loss: 0.535   lengthscale: 36.090   noise: 0.043
# Iter 284/500 - Loss: 0.534   lengthscale: 36.160   noise: 0.043
# Iter 285/500 - Loss: 0.534   lengthscale: 36.230   noise: 0.043
# Iter 286/500 - Loss: 0.534   lengthscale: 36.300   noise: 0.043
# Iter 287/500 - Loss: 0.534   lengthscale: 36.369   noise: 0.043
# Iter 288/500 - Loss: 0.534   lengthscale: 36.438   noise: 0.043
# Iter 289/500 - Loss: 0.533   lengthscale: 36.507   noise: 0.043
# Iter 290/500 - Loss: 0.533   lengthscale: 36.576   noise: 0.043
# Iter 291/500 - Loss: 0.533   lengthscale: 36.644   noise: 0.043
# Iter 292/500 - Loss: 0.533   lengthscale: 36.712   noise: 0.043
# Iter 293/500 - Loss: 0.533   lengthscale: 36.779   noise: 0.043
# Iter 294/500 - Loss: 0.532   lengthscale: 36.846   noise: 0.043
# Iter 295/500 - Loss: 0.532   lengthscale: 36.913   noise: 0.043
# Iter 296/500 - Loss: 0.532   lengthscale: 36.980   noise: 0.043
# Iter 297/500 - Loss: 0.532   lengthscale: 37.046   noise: 0.043
# Iter 298/500 - Loss: 0.532   lengthscale: 37.112   noise: 0.043
# Iter 299/500 - Loss: 0.532   lengthscale: 37.178   noise: 0.043
# Iter 300/500 - Loss: 0.531   lengthscale: 37.244   noise: 0.043
# Iter 301/500 - Loss: 0.531   lengthscale: 37.309   noise: 0.043
# Iter 302/500 - Loss: 0.531   lengthscale: 37.374   noise: 0.043
# Iter 303/500 - Loss: 0.531   lengthscale: 37.439   noise: 0.043
# Iter 304/500 - Loss: 0.531   lengthscale: 37.503   noise: 0.043
# Iter 305/500 - Loss: 0.530   lengthscale: 37.567   noise: 0.043
# Iter 306/500 - Loss: 0.530   lengthscale: 37.631   noise: 0.043
# Iter 307/500 - Loss: 0.530   lengthscale: 37.695   noise: 0.043
# Iter 308/500 - Loss: 0.530   lengthscale: 37.758   noise: 0.043
# Iter 309/500 - Loss: 0.530   lengthscale: 37.821   noise: 0.043
# Iter 310/500 - Loss: 0.530   lengthscale: 37.884   noise: 0.043
# Iter 311/500 - Loss: 0.529   lengthscale: 37.947   noise: 0.043
# Iter 312/500 - Loss: 0.529   lengthscale: 38.009   noise: 0.043
# Iter 313/500 - Loss: 0.529   lengthscale: 38.072   noise: 0.043
# Iter 314/500 - Loss: 0.529   lengthscale: 38.134   noise: 0.043
# Iter 315/500 - Loss: 0.529   lengthscale: 38.195   noise: 0.043
# Iter 316/500 - Loss: 0.529   lengthscale: 38.257   noise: 0.043
# Iter 317/500 - Loss: 0.529   lengthscale: 38.318   noise: 0.043
# Iter 318/500 - Loss: 0.528   lengthscale: 38.379   noise: 0.043
# Iter 319/500 - Loss: 0.528   lengthscale: 38.440   noise: 0.043
# Iter 320/500 - Loss: 0.528   lengthscale: 38.500   noise: 0.043
# Iter 321/500 - Loss: 0.528   lengthscale: 38.561   noise: 0.043
# Iter 322/500 - Loss: 0.528   lengthscale: 38.621   noise: 0.043
# Iter 323/500 - Loss: 0.528   lengthscale: 38.681   noise: 0.043
# Iter 324/500 - Loss: 0.528   lengthscale: 38.740   noise: 0.043
# Iter 325/500 - Loss: 0.527   lengthscale: 38.800   noise: 0.043
# Iter 326/500 - Loss: 0.527   lengthscale: 38.859   noise: 0.043
# Iter 327/500 - Loss: 0.527   lengthscale: 38.918   noise: 0.043
# Iter 328/500 - Loss: 0.527   lengthscale: 38.977   noise: 0.043
# Iter 329/500 - Loss: 0.527   lengthscale: 39.035   noise: 0.043
# Iter 330/500 - Loss: 0.527   lengthscale: 39.094   noise: 0.044
# Iter 331/500 - Loss: 0.527   lengthscale: 39.152   noise: 0.044
# Iter 332/500 - Loss: 0.526   lengthscale: 39.210   noise: 0.044
# Iter 333/500 - Loss: 0.526   lengthscale: 39.268   noise: 0.044
# Iter 334/500 - Loss: 0.526   lengthscale: 39.325   noise: 0.044
# Iter 335/500 - Loss: 0.526   lengthscale: 39.383   noise: 0.044
# Iter 336/500 - Loss: 0.526   lengthscale: 39.440   noise: 0.044
# Iter 337/500 - Loss: 0.526   lengthscale: 39.497   noise: 0.044
# Iter 338/500 - Loss: 0.526   lengthscale: 39.554   noise: 0.044
# Iter 339/500 - Loss: 0.526   lengthscale: 39.611   noise: 0.044
# Iter 340/500 - Loss: 0.525   lengthscale: 39.667   noise: 0.044
# Iter 341/500 - Loss: 0.525   lengthscale: 39.723   noise: 0.044
# Iter 342/500 - Loss: 0.525   lengthscale: 39.780   noise: 0.044
# Iter 343/500 - Loss: 0.525   lengthscale: 39.836   noise: 0.044
# Iter 344/500 - Loss: 0.525   lengthscale: 39.891   noise: 0.044
# Iter 345/500 - Loss: 0.525   lengthscale: 39.947   noise: 0.044
# Iter 346/500 - Loss: 0.525   lengthscale: 40.002   noise: 0.044
# Iter 347/500 - Loss: 0.525   lengthscale: 40.058   noise: 0.044
# Iter 348/500 - Loss: 0.524   lengthscale: 40.113   noise: 0.044
# Iter 349/500 - Loss: 0.524   lengthscale: 40.168   noise: 0.044
# Iter 350/500 - Loss: 0.524   lengthscale: 40.222   noise: 0.044
# Iter 351/500 - Loss: 0.524   lengthscale: 40.277   noise: 0.044
# Iter 352/500 - Loss: 0.524   lengthscale: 40.331   noise: 0.044
# Iter 353/500 - Loss: 0.524   lengthscale: 40.386   noise: 0.044
# Iter 354/500 - Loss: 0.524   lengthscale: 40.440   noise: 0.044
# Iter 355/500 - Loss: 0.524   lengthscale: 40.494   noise: 0.044
# Iter 356/500 - Loss: 0.524   lengthscale: 40.547   noise: 0.044
# Iter 357/500 - Loss: 0.523   lengthscale: 40.601   noise: 0.044
# Iter 358/500 - Loss: 0.523   lengthscale: 40.654   noise: 0.044
# Iter 359/500 - Loss: 0.523   lengthscale: 40.708   noise: 0.044
# Iter 360/500 - Loss: 0.523   lengthscale: 40.761   noise: 0.044
# Iter 361/500 - Loss: 0.523   lengthscale: 40.814   noise: 0.044
# Iter 362/500 - Loss: 0.523   lengthscale: 40.867   noise: 0.044
# Iter 363/500 - Loss: 0.523   lengthscale: 40.920   noise: 0.044
# Iter 364/500 - Loss: 0.523   lengthscale: 40.972   noise: 0.044
# Iter 365/500 - Loss: 0.523   lengthscale: 41.025   noise: 0.044
# Iter 366/500 - Loss: 0.522   lengthscale: 41.077   noise: 0.044
# Iter 367/500 - Loss: 0.522   lengthscale: 41.129   noise: 0.044
# Iter 368/500 - Loss: 0.522   lengthscale: 41.181   noise: 0.044
# Iter 369/500 - Loss: 0.522   lengthscale: 41.233   noise: 0.044
# Iter 370/500 - Loss: 0.522   lengthscale: 41.285   noise: 0.044
# Iter 371/500 - Loss: 0.522   lengthscale: 41.336   noise: 0.044
# Iter 372/500 - Loss: 0.522   lengthscale: 41.388   noise: 0.044
# Iter 373/500 - Loss: 0.522   lengthscale: 41.439   noise: 0.044
# Iter 374/500 - Loss: 0.522   lengthscale: 41.490   noise: 0.044
# Iter 375/500 - Loss: 0.522   lengthscale: 41.541   noise: 0.044
# Iter 376/500 - Loss: 0.521   lengthscale: 41.592   noise: 0.045
# Iter 377/500 - Loss: 0.521   lengthscale: 41.643   noise: 0.045
# Iter 378/500 - Loss: 0.521   lengthscale: 41.694   noise: 0.045
# Iter 379/500 - Loss: 0.521   lengthscale: 41.744   noise: 0.045
# Iter 380/500 - Loss: 0.521   lengthscale: 41.795   noise: 0.045
# Iter 381/500 - Loss: 0.521   lengthscale: 41.845   noise: 0.045
# Iter 382/500 - Loss: 0.521   lengthscale: 41.895   noise: 0.045
# Iter 383/500 - Loss: 0.521   lengthscale: 41.945   noise: 0.045
# Iter 384/500 - Loss: 0.521   lengthscale: 41.995   noise: 0.045
# Iter 385/500 - Loss: 0.521   lengthscale: 42.045   noise: 0.045
# Iter 386/500 - Loss: 0.521   lengthscale: 42.095   noise: 0.045
# Iter 387/500 - Loss: 0.520   lengthscale: 42.144   noise: 0.045
# Iter 388/500 - Loss: 0.520   lengthscale: 42.194   noise: 0.045
# Iter 389/500 - Loss: 0.520   lengthscale: 42.243   noise: 0.045
# Iter 390/500 - Loss: 0.520   lengthscale: 42.293   noise: 0.045
# Iter 391/500 - Loss: 0.520   lengthscale: 42.342   noise: 0.045
# Iter 392/500 - Loss: 0.520   lengthscale: 42.391   noise: 0.045
# Iter 393/500 - Loss: 0.520   lengthscale: 42.440   noise: 0.045
# Iter 394/500 - Loss: 0.520   lengthscale: 42.489   noise: 0.045
# Iter 395/500 - Loss: 0.520   lengthscale: 42.537   noise: 0.045
# Iter 396/500 - Loss: 0.520   lengthscale: 42.586   noise: 0.045
# Iter 397/500 - Loss: 0.520   lengthscale: 42.634   noise: 0.045
# Iter 398/500 - Loss: 0.519   lengthscale: 42.683   noise: 0.045
# Iter 399/500 - Loss: 0.519   lengthscale: 42.731   noise: 0.045
# Iter 400/500 - Loss: 0.519   lengthscale: 42.779   noise: 0.045
# Iter 401/500 - Loss: 0.519   lengthscale: 42.827   noise: 0.045
# Iter 402/500 - Loss: 0.519   lengthscale: 42.875   noise: 0.045
# Iter 403/500 - Loss: 0.519   lengthscale: 42.923   noise: 0.045
# Iter 404/500 - Loss: 0.519   lengthscale: 42.971   noise: 0.045
# Iter 405/500 - Loss: 0.519   lengthscale: 43.019   noise: 0.045
# Iter 406/500 - Loss: 0.519   lengthscale: 43.066   noise: 0.045
# Iter 407/500 - Loss: 0.519   lengthscale: 43.114   noise: 0.045
# Iter 408/500 - Loss: 0.519   lengthscale: 43.161   noise: 0.045
# Iter 409/500 - Loss: 0.519   lengthscale: 43.209   noise: 0.045
# Iter 410/500 - Loss: 0.518   lengthscale: 43.256   noise: 0.045
# Iter 411/500 - Loss: 0.518   lengthscale: 43.303   noise: 0.045
# Iter 412/500 - Loss: 0.518   lengthscale: 43.350   noise: 0.045
# Iter 413/500 - Loss: 0.518   lengthscale: 43.397   noise: 0.045
# Iter 414/500 - Loss: 0.518   lengthscale: 43.444   noise: 0.045
# Iter 415/500 - Loss: 0.518   lengthscale: 43.491   noise: 0.045
# Iter 416/500 - Loss: 0.518   lengthscale: 43.538   noise: 0.045
# Iter 417/500 - Loss: 0.518   lengthscale: 43.584   noise: 0.045
# Iter 418/500 - Loss: 0.518   lengthscale: 43.631   noise: 0.045
# Iter 419/500 - Loss: 0.518   lengthscale: 43.677   noise: 0.045
# Iter 420/500 - Loss: 0.518   lengthscale: 43.724   noise: 0.045
# Iter 421/500 - Loss: 0.518   lengthscale: 43.770   noise: 0.046
# Iter 422/500 - Loss: 0.518   lengthscale: 43.816   noise: 0.046
# Iter 423/500 - Loss: 0.517   lengthscale: 43.862   noise: 0.046
# Iter 424/500 - Loss: 0.517   lengthscale: 43.908   noise: 0.046
# Iter 425/500 - Loss: 0.517   lengthscale: 43.954   noise: 0.046
# Iter 426/500 - Loss: 0.517   lengthscale: 44.000   noise: 0.046
# Iter 427/500 - Loss: 0.517   lengthscale: 44.046   noise: 0.046
# Iter 428/500 - Loss: 0.517   lengthscale: 44.092   noise: 0.046
# Iter 429/500 - Loss: 0.517   lengthscale: 44.137   noise: 0.046
# Iter 430/500 - Loss: 0.517   lengthscale: 44.183   noise: 0.046
# Iter 431/500 - Loss: 0.517   lengthscale: 44.228   noise: 0.046
# Iter 432/500 - Loss: 0.517   lengthscale: 44.274   noise: 0.046
# Iter 433/500 - Loss: 0.517   lengthscale: 44.319   noise: 0.046
# Iter 434/500 - Loss: 0.517   lengthscale: 44.364   noise: 0.046
# Iter 435/500 - Loss: 0.517   lengthscale: 44.410   noise: 0.046
# Iter 436/500 - Loss: 0.517   lengthscale: 44.455   noise: 0.046
# Iter 437/500 - Loss: 0.516   lengthscale: 44.500   noise: 0.046
# Iter 438/500 - Loss: 0.516   lengthscale: 44.545   noise: 0.046
# Iter 439/500 - Loss: 0.516   lengthscale: 44.590   noise: 0.046
# Iter 440/500 - Loss: 0.516   lengthscale: 44.635   noise: 0.046
# Iter 441/500 - Loss: 0.516   lengthscale: 44.679   noise: 0.046
# Iter 442/500 - Loss: 0.516   lengthscale: 44.724   noise: 0.046
# Iter 443/500 - Loss: 0.516   lengthscale: 44.769   noise: 0.046
# Iter 444/500 - Loss: 0.516   lengthscale: 44.814   noise: 0.046
# Iter 445/500 - Loss: 0.516   lengthscale: 44.858   noise: 0.046
# Iter 446/500 - Loss: 0.516   lengthscale: 44.903   noise: 0.046
# Iter 447/500 - Loss: 0.516   lengthscale: 44.947   noise: 0.046
# Iter 448/500 - Loss: 0.516   lengthscale: 44.991   noise: 0.046
# Iter 449/500 - Loss: 0.516   lengthscale: 45.036   noise: 0.046
# Iter 450/500 - Loss: 0.516   lengthscale: 45.080   noise: 0.046
# Iter 451/500 - Loss: 0.516   lengthscale: 45.124   noise: 0.046
# Iter 452/500 - Loss: 0.515   lengthscale: 45.168   noise: 0.046
# Iter 453/500 - Loss: 0.515   lengthscale: 45.212   noise: 0.046
# Iter 454/500 - Loss: 0.515   lengthscale: 45.256   noise: 0.046
# Iter 455/500 - Loss: 0.515   lengthscale: 45.300   noise: 0.046
# Iter 456/500 - Loss: 0.515   lengthscale: 45.344   noise: 0.046
# Iter 457/500 - Loss: 0.515   lengthscale: 45.388   noise: 0.046
# Iter 458/500 - Loss: 0.515   lengthscale: 45.432   noise: 0.046
# Iter 459/500 - Loss: 0.515   lengthscale: 45.475   noise: 0.046
# Iter 460/500 - Loss: 0.515   lengthscale: 45.519   noise: 0.046
# Iter 461/500 - Loss: 0.515   lengthscale: 45.563   noise: 0.046
# Iter 462/500 - Loss: 0.515   lengthscale: 45.606   noise: 0.046
# Iter 463/500 - Loss: 0.515   lengthscale: 45.650   noise: 0.046
# Iter 464/500 - Loss: 0.515   lengthscale: 45.693   noise: 0.046
# Iter 465/500 - Loss: 0.515   lengthscale: 45.737   noise: 0.046
# Iter 466/500 - Loss: 0.515   lengthscale: 45.780   noise: 0.046
# Iter 467/500 - Loss: 0.514   lengthscale: 45.823   noise: 0.047
# Iter 468/500 - Loss: 0.514   lengthscale: 45.867   noise: 0.047
# Iter 469/500 - Loss: 0.514   lengthscale: 45.910   noise: 0.047
# Iter 470/500 - Loss: 0.514   lengthscale: 45.953   noise: 0.047
# Iter 471/500 - Loss: 0.514   lengthscale: 45.996   noise: 0.047
# Iter 472/500 - Loss: 0.514   lengthscale: 46.039   noise: 0.047
# Iter 473/500 - Loss: 0.514   lengthscale: 46.082   noise: 0.047
# Iter 474/500 - Loss: 0.514   lengthscale: 46.125   noise: 0.047
# Iter 475/500 - Loss: 0.514   lengthscale: 46.168   noise: 0.047
# Iter 476/500 - Loss: 0.514   lengthscale: 46.211   noise: 0.047
# Iter 477/500 - Loss: 0.514   lengthscale: 46.254   noise: 0.047
# Iter 478/500 - Loss: 0.514   lengthscale: 46.297   noise: 0.047
# Iter 479/500 - Loss: 0.514   lengthscale: 46.339   noise: 0.047
# Iter 480/500 - Loss: 0.514   lengthscale: 46.382   noise: 0.047
# Iter 481/500 - Loss: 0.514   lengthscale: 46.425   noise: 0.047
# Iter 482/500 - Loss: 0.514   lengthscale: 46.467   noise: 0.047
# Iter 483/500 - Loss: 0.514   lengthscale: 46.510   noise: 0.047
# Iter 484/500 - Loss: 0.513   lengthscale: 46.553   noise: 0.047
# Iter 485/500 - Loss: 0.513   lengthscale: 46.595   noise: 0.047
# Iter 486/500 - Loss: 0.513   lengthscale: 46.638   noise: 0.047
# Iter 487/500 - Loss: 0.513   lengthscale: 46.680   noise: 0.047
# Iter 488/500 - Loss: 0.513   lengthscale: 46.722   noise: 0.047
# Iter 489/500 - Loss: 0.513   lengthscale: 46.765   noise: 0.047
# Iter 490/500 - Loss: 0.513   lengthscale: 46.807   noise: 0.047
# Iter 491/500 - Loss: 0.513   lengthscale: 46.849   noise: 0.047
# Iter 492/500 - Loss: 0.513   lengthscale: 46.892   noise: 0.047
# Iter 493/500 - Loss: 0.513   lengthscale: 46.934   noise: 0.047
# Iter 494/500 - Loss: 0.513   lengthscale: 46.976   noise: 0.047
# Iter 495/500 - Loss: 0.513   lengthscale: 47.018   noise: 0.047
# Iter 496/500 - Loss: 0.513   lengthscale: 47.060   noise: 0.047
# Iter 497/500 - Loss: 0.513   lengthscale: 47.102   noise: 0.047
# Iter 498/500 - Loss: 0.513   lengthscale: 47.144   noise: 0.047
# Iter 499/500 - Loss: 0.513   lengthscale: 47.186   noise: 0.047
# Iter 500/500 - Loss: 0.513   lengthscale: 47.228   noise: 0.047

# %% [markdown]
# Now, we test predictions. For simplicity, we will assume a fixed variance of $0.01.$

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1, 51)
    test_x_distributional = torch.stack((test_x, (1e-3 * torch.ones_like(test_x)).log()), dim=1)
    observed_pred = likelihood(model(test_x_distributional))

with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, figsize=(8, 3))

    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    ax.errorbar(train_x_mean.numpy(), train_y.numpy(), xerr=train_x_stdv, fmt='k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])

# %% [markdown]
# As a final note, we've made it very easy to extend the distributional kernel class by exposing a generic `DistributionalInputKernel` class that takes as input any distance function over probability distributions.
